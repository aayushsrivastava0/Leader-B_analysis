# %%
#Scatter_plots max and mean

# %%
import pandas as pd
import pandas as pd
import numpy as np
import scipy
from scipy.stats import skew
from scipy.stats import kurtosis
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_rows',None)

# %%
yearss = [2010, 2011, 2012, 2013,2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
yearss
# Out:
# [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]

# %%
random=r'C:\Users\Aayush Srivastava\Desktop\DATATATATA\mean_leaderboard_data_analysis\webinar_score.csv'
random_data= pd.read_csv(random)
random_data.shape
# Out:
# (230, 4)

# %%
random_data
# Out:
#                    studio_name  year quarter  webinar_score
# 0                 AI/ML Studio  2020      Q1          0.000
# 1                 AI/ML Studio  2020      Q2          0.000
# 2                 AI/ML Studio  2020      Q3          0.000
# 3                 AI/ML Studio  2020      Q4          0.000
# 4                 AI/ML Studio  2021      Q1          0.000
# 5                 AI/ML Studio  2021      Q2          0.000
# 6                 AI/ML Studio  2021      Q3          0.000
# 7                 AI/ML Studio  2021      Q4          0.000
# 8                 AI/ML Studio  2022      Q1          0.000
# 9           Account Management  2020      Q2          0.000
# 10          Account Management  2022      Q1          0.000
# 11                Agile Studio  2021      Q2          0.000
# 12                Agile Studio  2021      Q3          0.000
# 13                Agile Studio  2021      Q4          0.000
# 14                Agile Studio  2022      Q1          0.000
# 15               DevOps Studio  2019      Q1          0.000
# 16               DevOps Studio  2019      Q2          0.000
# 17               DevOps Studio  2019      Q3          0.000
# 18               DevOps Studio  2019      Q4          0.000
# 19               DevOps Studio  2020      Q1          0.000
# 20               DevOps Studio  2020      Q2          6.000
# 21               DevOps Studio  2020      Q3          0.000
# 22               DevOps Studio  2020      Q4          0.000
# 23               DevOps Studio  2021      Q1          0.000
# 24               DevOps Studio  2021      Q2          6.000
# 25               DevOps Studio  2021      Q3          3.000
# 26               DevOps Studio  2021      Q4          3.000
# 27               DevOps Studio  2022      Q1          0.000
# 28      Engineering Operations  2016      Q2          0.000
# 29      Engineering Operations  2018      Q1          0.000
# 30      Engineering Operations  2019      Q1          0.000
# 31      Engineering Operations  2019      Q2          0.000
# 32      Engineering Operations  2019      Q3          0.000
# 33      Engineering Operations  2019      Q4          0.000
# 34      Engineering Operations  2020      Q1          0.000
# 35      Engineering Operations  2021      Q1         15.000
# 36      Engineering Operations  2022      Q1          0.000
# 37             Frontend Studio  2019      Q1          0.000
# 38             Frontend Studio  2019      Q2          0.000
# 39             Frontend Studio  2019      Q3          0.000
# 40             Frontend Studio  2019      Q4          0.000
# 41             Frontend Studio  2020      Q2          0.000
# 42             Frontend Studio  2020      Q3          0.000
# 43             Frontend Studio  2020      Q4          0.000
# 44             Frontend Studio  2021      Q2          0.000
# 45             Frontend Studio  2021      Q3          3.000
# 46             Frontend Studio  2021      Q4          3.000
# 47             Frontend Studio  2022      Q1          0.000
# 48                     Interns  2022      Q1          0.000
# 49                 Java Studio  2015      Q2          0.000
# 50                 Java Studio  2015      Q3          0.000
# 51                 Java Studio  2015      Q4          0.000
# 52                 Java Studio  2016      Q1          0.000
# 53                 Java Studio  2016      Q2          0.000
# 54                 Java Studio  2016      Q3          0.000
# 55                 Java Studio  2016      Q4          0.000
# 56                 Java Studio  2017      Q1          0.000
# 57                 Java Studio  2017      Q3          0.000
# 58                 Java Studio  2017      Q4          0.000
# 59                 Java Studio  2018      Q2          0.000
# 60                 Java Studio  2018      Q3          0.000
# 61                 Java Studio  2018      Q4          0.000
# 62                 Java Studio  2019      Q1          0.000
# 63                 Java Studio  2019      Q2          0.000
# 64                 Java Studio  2019      Q3         15.000
# 65                 Java Studio  2019      Q4         15.000
# 66                 Java Studio  2020      Q1          3.750
# 67                 Java Studio  2020      Q2          0.000
# 68                 Java Studio  2020      Q3          3.000
# 69                 Java Studio  2020      Q4          3.000
# 70                 Java Studio  2021      Q1          0.000
# 71                 Java Studio  2021      Q2          0.000
# 72                 Java Studio  2021      Q3          6.000
# 73                 Java Studio  2021      Q4          6.000
# 74                 Java Studio  2022      Q1          0.000
# 75    Learning and Development  2021      Q2          0.000
# 76    Learning and Development  2021      Q3          0.000
# 77    Learning and Development  2021      Q4          0.000
# 78               Lightbend CoE  2014      Q1          0.000
# 79               Lightbend CoE  2014      Q2          0.000
# 80               Lightbend CoE  2014      Q3          0.000
# 81               Lightbend CoE  2014      Q4          0.000
# 82               Lightbend CoE  2015      Q1          0.000
# 83               Lightbend CoE  2015      Q2          0.000
# 84               Lightbend CoE  2015      Q3          0.000
# 85               Lightbend CoE  2015      Q4          0.000
# 86               Lightbend CoE  2016      Q1          0.000
# 87               Lightbend CoE  2016      Q2          0.000
# 88               Lightbend CoE  2016      Q3          0.000
# 89               Lightbend CoE  2016      Q4          0.000
# 90               Lightbend CoE  2017      Q1          0.000
# 91               Lightbend CoE  2017      Q2          0.000
# 92               Lightbend CoE  2017      Q3          0.000
# 93               Lightbend CoE  2017      Q4          0.000
# 94               Lightbend CoE  2018      Q1          0.000
# 95               Lightbend CoE  2018      Q2          0.000
# 96               Lightbend CoE  2019      Q1          0.000
# 97               Lightbend CoE  2019      Q2          0.000
# 98               Lightbend CoE  2019      Q3          0.000
# 99               Lightbend CoE  2019      Q4          0.000
# 100              Lightbend CoE  2020      Q1          0.000
# 101              Lightbend CoE  2020      Q2          0.000
# 102              Lightbend CoE  2020      Q3          0.000
# 103              Lightbend CoE  2020      Q4          0.000
# 104              Lightbend CoE  2021      Q1          0.000
# 105              Lightbend CoE  2021      Q2          0.000
# 106              Lightbend CoE  2021      Q3          0.000
# 107              Lightbend CoE  2021      Q4          0.000
# 108                 Management  2010      Q2          0.000
# 109                 Management  2010      Q3          0.000
# 110                 Management  2010      Q4          0.000
# 111                 Management  2011      Q1          0.000
# 112                 Management  2011      Q2          0.000
# 113                 Management  2011      Q3          0.000
# 114                 Management  2011      Q4          0.000
# 115                 Management  2012      Q1          0.000
# 116                 Management  2012      Q2          0.000
# 117                 Management  2012      Q3          0.000
# 118                 Management  2012      Q4          0.000
# 119                 Management  2013      Q1          0.000
# 120                 Management  2013      Q2          0.000
# 121                 Management  2013      Q3          0.000
# 122                 Management  2013      Q4          0.000
# 123                 Management  2014      Q1          0.000
# 124                 Management  2014      Q2          0.000
# 125                 Management  2014      Q3          0.000
# 126                 Management  2014      Q4          0.000
# 127                 Management  2015      Q2          0.000
# 128                 Management  2015      Q3          0.000
# 129                 Management  2015      Q4          0.000
# 130                 Management  2016      Q1          0.000
# 131                 Management  2016      Q2          0.000
# 132                 Management  2016      Q3          0.000
# 133                 Management  2016      Q4          0.000
# 134                 Management  2017      Q1          0.000
# 135                 Management  2017      Q2          0.000
# 136                 Management  2017      Q3          0.000
# 137                 Management  2017      Q4          0.000
# 138                 Management  2018      Q1          0.000
# 139                 Management  2018      Q2          0.000
# 140                 Management  2018      Q3          0.000
# 141                 Management  2018      Q4          0.000
# 142                 Management  2019      Q1          0.000
# 143                 Management  2019      Q2          0.000
# 144                 Management  2019      Q3          0.000
# 145                 Management  2019      Q4          0.000
# 146                 Management  2020      Q1          0.000
# 147                 Management  2020      Q2          0.000
# 148                 Management  2020      Q3          0.000
# 149                 Management  2020      Q4          0.000
# 150                 Management  2021      Q1          0.000
# 151                 Management  2022      Q1          0.000
# 152                  Marketing  2018      Q2          0.000
# 153                  Marketing  2018      Q3          0.000
# 154                  Marketing  2018      Q4          0.000
# 155                  Marketing  2019      Q1          0.000
# 156                  Marketing  2019      Q2          0.000
# 157                  Marketing  2019      Q3          0.000
# 158                  Marketing  2019      Q4          0.000
# 159                  Marketing  2020      Q1          0.000
# 160                  Marketing  2020      Q2          0.000
# 161                  Marketing  2020      Q3          0.000
# 162                  Marketing  2020      Q4          0.000
# 163                  Marketing  2021      Q1          0.000
# 164                  Marketing  2021      Q2          0.000
# 165                  Marketing  2021      Q3          0.000
# 166                  Marketing  2021      Q4          0.000
# 167                Rust Studio  2019      Q1          0.000
# 168                Rust Studio  2019      Q2          0.000
# 169                Rust Studio  2019      Q3          0.000
# 170                Rust Studio  2019      Q4          0.000
# 171                Rust Studio  2020      Q1          0.000
# 172                Rust Studio  2020      Q2         15.000
# 173                Rust Studio  2020      Q3          0.000
# 174                Rust Studio  2020      Q4          0.000
# 175                Rust Studio  2021      Q1         15.000
# 176                Rust Studio  2021      Q2          0.000
# 177                Rust Studio  2021      Q3          0.000
# 178                Rust Studio  2021      Q4          0.000
# 179                Rust Studio  2022      Q1          0.000
# 180               Scala Studio  2014      Q1          0.000
# 181               Scala Studio  2014      Q2          0.000
# 182               Scala Studio  2014      Q3          0.000
# 183               Scala Studio  2014      Q4          0.000
# 184               Scala Studio  2015      Q2          0.000
# 185               Scala Studio  2015      Q3          0.000
# 186               Scala Studio  2015      Q4          0.000
# 187               Scala Studio  2016      Q1          0.000
# 188               Scala Studio  2016      Q2          0.000
# 189               Scala Studio  2016      Q3          0.000
# 190               Scala Studio  2016      Q4          0.000
# 191               Scala Studio  2017      Q1          0.000
# 192               Scala Studio  2017      Q2          0.000
# 193               Scala Studio  2017      Q3          0.000
# 194               Scala Studio  2017      Q4          0.000
# 195               Scala Studio  2018      Q1          3.750
# 196               Scala Studio  2018      Q2          0.000
# 197               Scala Studio  2018      Q3          0.000
# 198               Scala Studio  2018      Q4          0.000
# 199               Scala Studio  2019      Q1          0.000
# 200               Scala Studio  2019      Q2          3.000
# 201               Scala Studio  2019      Q3          2.500
# 202               Scala Studio  2019      Q4          2.500
# 203               Scala Studio  2020      Q1          1.875
# 204               Scala Studio  2020      Q2          3.000
# 205               Scala Studio  2020      Q3          0.000
# 206               Scala Studio  2020      Q4          0.000
# 207               Scala Studio  2021      Q1          6.000
# 208               Scala Studio  2021      Q2          3.000
# 209               Scala Studio  2021      Q3          3.000
# 210               Scala Studio  2021      Q4          3.000
# 211               Scala Studio  2022      Q1          0.000
# 212  Testing Automation Studio  2016      Q1          0.000
# 213  Testing Automation Studio  2017      Q1          0.000
# 214  Testing Automation Studio  2018      Q1          0.000
# 215  Testing Automation Studio  2018      Q2          0.000
# 216  Testing Automation Studio  2018      Q3          0.000
# 217  Testing Automation Studio  2018      Q4          0.000
# 218  Testing Automation Studio  2019      Q2          0.000
# 219  Testing Automation Studio  2019      Q3          0.000
# 220  Testing Automation Studio  2019      Q4          0.000
# 221  Testing Automation Studio  2020      Q1          0.000
# 222  Testing Automation Studio  2020      Q2          0.000
# 223  Testing Automation Studio  2020      Q3          0.000
# 224  Testing Automation Studio  2020      Q4          0.000
# 225  Testing Automation Studio  2021      Q1          0.000
# 226  Testing Automation Studio  2021      Q2          0.000
# 227  Testing Automation Studio  2021      Q3          0.000
# 228  Testing Automation Studio  2021      Q4          0.000
# 229  Testing Automation Studio  2022      Q1          0.000

# %%
fig =plt.figure(figsize =(15,15))


for i in yearss:
    DF = random_data[((random_data['year'] == i) &(random_data['studio_name']== 'AI/ML Studio'))]

    
   
    plt.scatter(DF['quarter'], DF['webinar_score'], label = i )
    


plt.legend(fontsize=10)
plt.xlabel('Quarters')
plt.ylabel('webinar_score')

plt.savefig('AIML.png')

# %%
fig =plt.figure(figsize =(15,15))


for i in yearss:
    DF = random_data[((random_data['year'] == i) &(random_data['studio_name']== 'Scala Studio'))]

    
   
    plt.scatter(DF['quarter'], DF['webinar_score'], label = i )
    


plt.legend(fontsize=10)
plt.xlabel('Quarters')
plt.ylabel('webinar_score')

plt.savefig('SCALA.png')

# %%
fig =plt.figure(figsize =(15,15))


for i in yearss:
    DF = random_data[((random_data['year'] == i) &(random_data['studio_name']== 'Java Studio'))]

    
   
    plt.scatter(DF['quarter'], DF['webinar_score'], label = i )
    


plt.legend(fontsize=10)
plt.xlabel('Quarters')
plt.ylabel('webinar_score')

plt.savefig('java.png')

# %%
fig =plt.figure(figsize =(15,15))


for i in yearss:
    DF = random_data[((random_data['year'] == i) &(random_data['studio_name']== 'Testing Automation Studio'))]

    
   
    plt.scatter(DF['quarter'], DF['webinar_score'], label = i )
    


plt.legend(fontsize=10)
plt.xlabel('Quarters')
plt.ylabel('webinar_score')

plt.savefig('testing_auto.png')

# %%
fig =plt.figure(figsize =(15,15))


for i in yearss:
    DF = random_data[((random_data['year'] == i) &(random_data['studio_name']== 'DevOps Studio'))]

    
   
    plt.scatter(DF['quarter'], DF['webinar_score'], label = i )
    


plt.legend(fontsize=10)
plt.xlabel('Quarters')
plt.ylabel('webinar_score')

plt.savefig('devops.png')

# %%
fig =plt.figure(figsize =(15,15))


for i in yearss:
    DF = random_data[((random_data['year'] == i) &(random_data['studio_name']== 'Marketing'))]

    
   
    plt.scatter(DF['quarter'], DF['webinar_score'], label = i )
    


plt.legend(fontsize=10)
plt.xlabel('Quarters')
plt.ylabel('webinar_score')

plt.savefig('marketing.png')

# %%
fig =plt.figure(figsize =(15,15))


for i in yearss:
    DF = random_data[((random_data['year'] == i) &(random_data['studio_name']== 'Lightbend CoE'))]

    
   
    plt.scatter(DF['quarter'], DF['webinar_score'], label = i )
    


plt.legend(fontsize=10)
plt.xlabel('Quarters')
plt.ylabel('webinar_score')

plt.savefig('lightbend.png')

# %%
fig =plt.figure(figsize =(15,15))


for i in yearss:
    DF = random_data[((random_data['year'] == i) &(random_data['studio_name']== 'Management'))]

    
   
    plt.scatter(DF['quarter'], DF['webinar_score'], label = i )
    


plt.legend(fontsize=10)
plt.xlabel('Quarters')
plt.ylabel('webinar_score')

plt.savefig('management.png')

# %%
fig =plt.figure(figsize =(15,15))


for i in yearss:
    DF = random_data[((random_data['year'] == i) &(random_data['studio_name']== 'Rust Studio'))]

    
   
    plt.scatter(DF['quarter'], DF['webinar_score'], label = i )
    


plt.legend(fontsize=10)
plt.xlabel('Quarters')
plt.ylabel('webinar_score')

plt.savefig('rust.png')

# %%
fig =plt.figure(figsize =(15,15))


for i in yearss:
    DF = random_data[((random_data['year'] == i) &(random_data['studio_name']== 'Engineering Operations'))]

    
   
    plt.scatter(DF['quarter'], DF['webinar_score'], label = i )
    


plt.legend(fontsize=10)
plt.xlabel('Quarters')
plt.ylabel('webinar_score')

plt.savefig('eng_ops.png')

# %%
fig =plt.figure(figsize =(15,15))


for i in yearss:
    DF = random_data[((random_data['year'] == i) &(random_data['studio_name']== 'Frontend Studio'))]

    
   
    plt.scatter(DF['quarter'], DF['webinar_score'], label = i )
    


plt.legend(fontsize=10)
plt.xlabel('Quarters')
plt.ylabel('webinar_score')

plt.savefig('frontend.png')

# %%
fig =plt.figure(figsize =(15,15))


for i in yearss:
    DF = random_data[((random_data['year'] == i) &(random_data['studio_name']== 'Account Management'))]

    
   
    plt.scatter(DF['quarter'], DF['webinar_score'], label = i )
    


plt.legend(fontsize=10)
plt.xlabel('Quarters')
plt.ylabel('webinar_score')

plt.savefig('account_ma.png')

# %%
fig =plt.figure(figsize =(15,15))


for i in yearss:
    DF = random_data[((random_data['year'] == i) &(random_data['studio_name']== 'Learning and Development'))]

    
   
    plt.scatter(DF['quarter'], DF['webinar_score'], label = i )
    


plt.legend(fontsize=10)
plt.xlabel('Quarters')
plt.ylabel('webinar_score')

plt.savefig('learningdev.png')

# %%
fig =plt.figure(figsize =(15,15))


for i in yearss:
    DF = random_data[((random_data['year'] == i) &(random_data['studio_name']== 'Agile Studio'))]

    
   
    plt.scatter(DF['quarter'], DF['webinar_score'], label = i )
    


plt.legend(fontsize=10)
plt.xlabel('Quarters')
plt.ylabel('webinar_score')

plt.savefig('agile.png')

# %%
fig =plt.figure(figsize =(15,15))


for i in yearss:
    DF = random_data[((random_data['year'] == i) &(random_data['studio_name']== 'Interns'))]

    
   
    plt.scatter(DF['quarter'], DF['webinar_score'], label = i )
    


plt.legend(fontsize=10)
plt.xlabel('Quarters')
plt.ylabel('webinar_score')

plt.savefig('interns.png')
